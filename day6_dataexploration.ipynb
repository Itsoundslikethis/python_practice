# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print ("Notebook works")
# Out:
# Notebook works

# %%
import pandas as pd
df = pd.read_csv("day6_fake_data.csv")
df
# Out:
#       name  age  salary
# 0    Alice   25   60000
# 1      Bob   30   72000
# 2  Charlie   35   81000
# 3    Diana   28   65000
# 4   Edward   40   95000

# %%
import os
os.getcwd()
# Out:
# 'C:\\coding_practice'

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'cleaned_text.txt',
#  'day1_loops.py',
#  'day2_practice',
#  'day3_practice',
#  'day4_practice',
#  'day4_sampletext.txt',
#  'day5_practice',
#  'day5_sampletext.txt',
#  'day6_dataexploration.ipynb',
#  'day6_fake_data.csv',
#  'day6_practice']

# %%
df.head()
# Out:
#       name  age  salary
# 0    Alice   25   60000
# 1      Bob   30   72000
# 2  Charlie   35   81000
# 3    Diana   28   65000
# 4   Edward   40   95000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   age     5 non-null      int64
#  2   salary  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.describe()
# Out:
#             age        salary
# count   5.00000      5.000000
# mean   31.60000  74600.000000
# std     5.94138  13867.227553
# min    25.00000  60000.000000
# 25%    28.00000  65000.000000
# 50%    30.00000  72000.000000
# 75%    35.00000  81000.000000
# max    40.00000  95000.000000

# %%
df.isna().sum()
# Out:
# name      0
# age       0
# salary    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x=df['name'], y=df['salary'])
plt.title("salary by Employee")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.sort_values(by="salary", ascending =False)
# Out:
#       name  age  salary
# 4   Edward   40   95000
# 2  Charlie   35   81000
# 1      Bob   30   72000
# 3    Diana   28   65000
# 0    Alice   25   60000

# %%
df[df["salary"] > 70000]
# Out:
#       name  age  salary
# 1      Bob   30   72000
# 2  Charlie   35   81000
# 4   Edward   40   95000

# %%
df["salary"].mean()
# Out:
# np.float64(74600.0)

# %%
df.loc[df["salary"].idxmax()]
# Out:
# name      Edward
# age           40
# salary     95000
# Name: 4, dtype: object

# %%
df[["age", "salary"]].corr()
# Out:
#              age    salary
# age     1.000000  0.995868
# salary  0.995868  1.000000

# %%
plt.scatter(df["age"], df["salary"])
plt.xlabel("Age")
plt.ylabel("Salary")

plt.title("Age vs Salary Trend")
plt.show()

# %%
sns.regplot(x="age", y="salary", data=df)
plt.title("Age vs Salary Trend")
plt.show()
